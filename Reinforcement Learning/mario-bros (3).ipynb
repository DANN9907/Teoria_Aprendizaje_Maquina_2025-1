# %% [markdown]
# <pre>
# ──────────────███████──███████
# ──────────████▓▓▓▓▓▓████░░░░░██
# ────────██▓▓▓▓▓▓▓▓▓▓▓▓██░░░░░░██
# ──────██▓▓▓▓▓▓████████████░░░░██
# ────██▓▓▓▓▓▓████████████████░██
# ────██▓▓████░░░░░░░░░░░░██████
# ──████████░░░░░░██░░██░░██▓▓▓▓██
# ──██░░████░░░░░░██░░██░░██▓▓▓▓██
# ██░░░░██████░░░░░░░░░░░░░░██▓▓██
# ██░░░░░░██░░░░██░░░░░░░░░░██▓▓██
# ──██░░░░░░░░░███████░░░░██████
# ────████░░░░░░░███████████▓▓██
# ──────██████░░░░░░░░░░██▓▓▓▓██
# ────██▓▓▓▓██████████████▓▓██
# ──██▓▓▓▓▓▓▓▓████░░░░░░████
# ████▓▓▓▓▓▓▓▓██░░░░░░░░░░██
# ████▓▓▓▓▓▓▓▓██░░░░░░░░░░██
# ██████▓▓▓▓▓▓▓▓██░░░░░░████████
# ──██████▓▓▓▓▓▓████████████████
# ────██████████████████████▓▓▓▓██
# ──██▓▓▓▓████████████████▓▓▓▓▓▓██
# ████▓▓██████████████████▓▓▓▓▓▓██
# ██▓▓▓▓██████████████████▓▓▓▓▓▓██
# ██▓▓▓▓██████████──────██▓▓▓▓████
# ██▓▓▓▓████──────────────██████
# ──████
# </pre>

# %%
# !pip install gym-super-mario-bros
# Out:
# Collecting gym-super-mario-bros
#   Downloading gym_super_mario_bros-7.4.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 19.9 MB/s eta 0:00:01
# Collecting nes-py>=8.1.4
#   Downloading nes_py-8.2.1.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 6.3 MB/s  eta 0:00:01
# Requirement already satisfied: gym>=0.17.2 in /opt/conda/lib/python3.7/site-packages (from nes-py>=8.1.4->gym-super-mario-bros) (0.17.3)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.7/site-packages (from nes-py>=8.1.4->gym-super-mario-bros) (1.18.5)
# Requirement already satisfied: pyglet<=1.5.21,>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from nes-py>=8.1.4->gym-super-mario-bros) (1.5.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.7/site-packages (from nes-py>=8.1.4->gym-super-mario-bros) (1.18.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gym>=0.17.2->nes-py>=8.1.4->gym-super-mario-bros) (1.6.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from gym>=0.17.2->nes-py>=8.1.4->gym-super-mario-bros) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.21,>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from nes-py>=8.1.4->gym-super-mario-bros) (1.5.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from pyglet<=1.5.21,>=1.4.0->nes-py>=8.1.4->gym-super-mario-bros) (0.18.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.7/site-packages (from nes-py>=8.1.4->gym-super-mario-bros) (1.18.5)
# Collecting tqdm>=4.48.2
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.5 MB/s  eta 0:00:01
# Building wheels for collected packages: nes-py
#   Building wheel for nes-py (setup.py) ... done
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp37-cp37m-linux_x86_64.whl size=433898 sha256=73ba173b8c95111ca7e4d82481f17160681a1697cc2b54be26d0bfe2267ce851
#   Stored in directory: /root/.cache/pip/wheels/17/96/0e/22a8c7dbdf412d8e988286f223b223baf0f4ad90c9e699c56d
# Successfully built nes-py
# Installing collected packages: tqdm, nes-py, gym-super-mario-bros
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.45.0
#     Uninstalling tqdm-4.45.0:
#       Successfully uninstalled tqdm-4.45.0
# Successfully installed gym-super-mario-bros-7.4.0 nes-py-8.2.1 tqdm-4.67.1
# WARNING: You are using pip version 20.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import torch
from torch import nn
from torchvision import transforms as T

import time, datetime
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from pathlib import Path
from collections import deque
import random, datetime, os, copy

import gym
from gym.spaces import Box
from gym.wrappers import FrameStack

from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# change directory
import os
os.chdir('/kaggle/input/gym-super-mario-bros')

# install controller
# !pip --disable-pip-version-check install -q nes_py
from nes_py.wrappers import JoypadSpace

import gym_super_mario_bros

# %% [markdown]
# # Initialize Environment

# %%
# Initialize Super Mario environment
env = gym_super_mario_bros.make("SuperMarioBros-1-1-v0")

# Limit the action-space to
#   0. walk right
#   1. jump right
env = JoypadSpace(env, SIMPLE_MOVEMENT)

env.reset()
next_state, reward, done, info = env.step(action=0)
print(f"{next_state.shape},\n {reward},\n {done},\n {info}")
# Out:
# (240, 256, 3),
#  0.0,
#  False,
#  {'coins': 0, 'flag_get': False, 'life': 2, 'score': 0, 'stage': 1, 'status': 'small', 'time': 400, 'world': 1, 'x_pos': 40, 'y_pos': 79}

# %% [markdown]
# # Preprocess Environment

# %%
class SkipFrame(gym.Wrapper):
    '''
        Custom wrapper that inherits from gy.Wrapper and implements the step() function.
        Use it to return only every skip nth frame
    '''
    def __init__(self, env, skip):
        super().__init__(env)
        self._skip = skip
        
    def step(self, action):
        total_reward = 0.0
        done = False
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        return obs, total_reward, done, info

# %%
class GrayScaleObservation(gym.ObservationWrapper):
    '''
        Common wrapper to transform an RGB image to grayscale; doing so reduces the size of the state representation without losing useful information.
        Now the size of each state: [1, 240, 256]
    '''
    def __init__(self, env):
        super().__init__(env)
        obs_shape = self.observation_space.shape[:2]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)
        self.transform = T.Grayscale()
    
    def permute_orientation(self, observation):
        observation = np.transpose(observation, (2, 0, 1))
        return torch.tensor(observation.copy(), dtype=torch.float)
    
    def observation(self, observation):
        observation = self.permute_orientation(observation)
        return self.transform(observation)

# %%
class ResizeObservation(gym.ObservationWrapper):
    '''
        Downsamples each observation into a square image.
        New size: [1, 84, 84]
    '''
    def __init__(self, env, shape):
        super().__init__(env)
        if isinstance(shape, int): self.shape = (shape, shape)
        else: self.shape = tuple(shape)

        obs_shape = self.shape + self.observation_space.shape[2:]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)
        
    def observation(self, observation):
        transforms = T.Compose([T.Resize(self.shape), T.Normalize(0, 255)])
        return transforms(observation).squeeze(0)

# %%
# preprocess environment
env = SkipFrame(env, skip=4)
env = GrayScaleObservation(env)
env = ResizeObservation(env, shape=84)
env = FrameStack(env, num_stack=4)

# %% [markdown]
# # Double Deep Q-Networks

# %%
class MarioNet(nn.Module):
    """
        input -> (conv2d + relu) x 3 -> flatten -> (dense + relu) x 2 -> output
    """
    def __init__(self, input_dim, output_dim):
        super().__init__()
        c, w, h = input_dim
        
        if h != 84: raise ValueError(f"Expecting input height: 84, got: {h}")
        if w != 84: raise ValueError(f"Expecting input width: 84, got: {w}")
            
        self.online = nn.Sequential(
            nn.Conv2d(in_channels=c, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim)
        )
        
        self.target = copy.deepcopy(self.online)
        
        # freeze Q-target parameters
        for p in self.target.parameters():
            p.requires_grad = False
            
    def forward(self, input, model):
        if model == "online":
            return self.online(input)
        elif model == "target":
            return self.target(input)

# %% [markdown]
# # Agent

# %%
class Mario:
    '''
        Mario randomly explores with a chance of self.exploration_rate.
        When he chooses to exploit, he relies on MarioNet to provide the most optimal action.
    '''
    def __init__(self, state_dim, action_dim, use_cuda):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.use_cuda = use_cuda
        self.memory = deque(maxlen=20000)
        self.batch_size = 16
        
        self.net = MarioNet(self.state_dim, self.action_dim).float()
        if self.use_cuda:
            self.net = self.net.to(device="cuda")
        
        self.exploration_rate = 1
        self.exploration_rate_decay = 0.99999975
        self.exploration_rate_min = 0.1
        self.curr_step = 0

        self.save_every = 5e5
    
    
    def act(self, state):
        '''
            Given a state, choose an epsilon-greedy action and update value of step.
        '''
        # Exploration
        if np.random.rand() < self.exploration_rate:
            action_idx = np.random.randint(self.action_dim)
        
        # Exploitation
        else:
            state = torch.tensor(state.__array__(), device=self.device).unsqueeze(0)
            action_values = self.net(state, model="online")
            action_idx = torch.argmax(action_values, axis=1).item()
        
        # Decrease exploration_rate
        self.exploration_rate *= self.exploration_rate_decay
        self.exploration_rate = max(self.exploration_rate_min, self.exploration_rate)
        
        # Increment step
        self.curr_step += 1
        return action_idx
    
    
    def cache(self, state, next_state, action, reward, done):
        """
            Store the experience to self.memory (replay buffer).
        """
        # Convertir a numpy uint8 comprimido
        state = (state.__array__() * 255).astype(np.uint8)
        next_state = (next_state.__array__() * 255).astype(np.uint8)
    
        # Guardar solo números puros
        self.memory.append((state, next_state, int(action), float(reward), bool(done)))

        
    def recall(self):
        batch = random.sample(self.memory, self.batch_size)
        states, next_states, actions, rewards, dones = zip(*batch)
    
        # Reconstruir tensores desde numpy y normalizarlos
        state = torch.tensor(np.array(states) / 255, dtype=torch.float32)
        next_state = torch.tensor(np.array(next_states) / 255, dtype=torch.float32)
        action = torch.tensor(actions)
        reward = torch.tensor(rewards)
        done = torch.tensor(dones)
    
        if self.use_cuda:
            state = state.cuda()
            next_state = next_state.cuda()
            action = action.cuda()
            reward = reward.cuda()
            done = done.cuda()
    
        return state, next_state, action, reward, done

# %% [markdown]
# # TD Estimate & TD Target

# %%
class Mario(Mario):
    def __init__(self, state_dim, action_dim, use_cuda):
        super().__init__(state_dim, action_dim, use_cuda)
        self.device = torch.device("cuda" if use_cuda else "cpu")
        self.net = self.net.to(self.device)
        self.gamma = 0.9
        self.burnin = 1e4
        self.learn_every = 6
        self.sync_every = 1e4
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=0.00025)
        self.loss_fn = torch.nn.SmoothL1Loss()


        
    def td_estimate(self, state, action):
        current_Q = self.net(state, model="online")[
            np.arange(0, self.batch_size), action
        ]
        return current_Q

    
    @torch.no_grad()
    def td_target(self, reward, next_state, done):
        next_state_Q = self.net(next_state, model="online")
        best_action = torch.argmax(next_state_Q, axis=1)
        next_Q = self.net(next_state, model="target")[
            np.arange(0, self.batch_size), best_action
        ]
        return (reward + (1 - done.float()) * self.gamma * next_Q).float()
    
    
    def update_Q_online(self, td_estimate, td_target):
        loss = self.loss_fn(td_estimate, td_target)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item()

    
    def sync_Q_target(self):
        self.net.target.load_state_dict(self.net.online.state_dict())
        
    
    def learn(self):
        if self.curr_step % self.sync_every == 0: self.sync_Q_target()
        #if self.curr_step % self.save_every == 0: self.save()
        if self.curr_step < self.burnin: return None, None
        if self.curr_step % self.learn_every != 0: return None, None

        # Sample from memory
        state, next_state, action, reward, done = self.recall()
        
        # Mover a GPU
        state = state.to(self.device)
        next_state = next_state.to(self.device)
        action = action.to(self.device)
        reward = reward.to(self.device)
        done = done.to(self.device)
        
        # Get TD Estimate
        td_est = self.td_estimate(state, action)
        
        # Get TD Target
        td_tgt = self.td_target(reward, next_state, done)
        
        # Backpropagate loss through Q_online
        loss = self.update_Q_online(td_est, td_tgt)
        
        return (td_est.mean().item(), loss)

# %% [markdown]
# # Logging

# %%
class MetricLogger:
    def __init__(self):
        # history metrics
        self.ep_rewards = []
        self.ep_lengths = []
        self.ep_avg_losses = []
        self.ep_avg_qs = []

        # moving averages, added for every call to record()
        self.moving_avg_ep_rewards = []
        self.moving_avg_ep_lengths = []
        self.moving_avg_ep_avg_losses = []
        self.moving_avg_ep_avg_qs = []

        # current episode metric
        self.init_episode()

        # timing
        self.record_time = time.time()

    def log_step(self, reward, loss, q):
        self.curr_ep_reward += reward
        self.curr_ep_length += 1
        if loss:
            self.curr_ep_loss += loss
            self.curr_ep_q += q
            self.curr_ep_loss_length += 1

    def log_episode(self):
        self.ep_rewards.append(self.curr_ep_reward)
        self.ep_lengths.append(self.curr_ep_length)
        if self.curr_ep_loss_length == 0:
            ep_avg_loss = 0
            ep_avg_q = 0
        else:
            ep_avg_loss = np.round(self.curr_ep_loss / self.curr_ep_loss_length, 5)
            ep_avg_q = np.round(self.curr_ep_q / self.curr_ep_loss_length, 5)
        self.ep_avg_losses.append(ep_avg_loss)
        self.ep_avg_qs.append(ep_avg_q)

        self.init_episode()

    def init_episode(self):
        self.curr_ep_reward = 0.0
        self.curr_ep_length = 0
        self.curr_ep_loss = 0.0
        self.curr_ep_q = 0.0
        self.curr_ep_loss_length = 0

    def record(self, episode, epsilon, step):
        mean_ep_reward = np.round(np.mean(self.ep_rewards[-100:]), 3)
        mean_ep_length = np.round(np.mean(self.ep_lengths[-100:]), 3)
        mean_ep_loss = np.round(np.mean(self.ep_avg_losses[-100:]), 3)
        mean_ep_q = np.round(np.mean(self.ep_avg_qs[-100:]), 3)
        self.moving_avg_ep_rewards.append(mean_ep_reward)
        self.moving_avg_ep_lengths.append(mean_ep_length)
        self.moving_avg_ep_avg_losses.append(mean_ep_loss)
        self.moving_avg_ep_avg_qs.append(mean_ep_q)

        last_record_time = self.record_time
        self.record_time = time.time()
        time_since_last_record = np.round(self.record_time - last_record_time, 3)

        print(
            "Episode:{:4d}  :: Step:{:5d}  :: Epsilon:{:8.3f}  :: Mean_Reward:{:8.3f}  :: " \
            "Mean_Length:{:8.3f}  :: Mean_Loss:{:4.3f}  :: Mean_Q_Value:{:8.3f}  :: " \
            "Time_Delta:{:8.3f} "
            .format(episode, step, epsilon, mean_ep_reward, mean_ep_length, 
                    mean_ep_loss, mean_ep_q, time_since_last_record)
        )

# %% [markdown]
# # Training

# %%
import gc
use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

mario = Mario(state_dim=(4, 84, 84), action_dim=env.action_space.n, use_cuda=use_cuda)

logger = MetricLogger()

best_mean_reward = -float('inf')  # Inicializamos el mejor reward con un valor muy bajo

episodes = 2001
for e in range(episodes):

    state = env.reset()

    # Play the game!
    while True:

        # Run agent on the state
        action = mario.act(state)

        # Agent performs action
        next_state, reward, done, info = env.step(action)

        # Remember
        mario.cache(state, next_state, action, reward, done)

        # Learn
        q, loss = mario.learn()

        # Logging
        logger.log_step(reward, loss, q)

        # Update state
        state = next_state

        # Check if end of game
        if done or info["flag_get"]:
            break

    logger.log_episode()

    if e % 25 == 0:
        logger.record(episode=e, epsilon=mario.exploration_rate, step=mario.curr_step)

        # Evaluar recompensa promedio de los últimos 100 episodios
        mean_reward = np.mean(logger.ep_rewards[-100:])

        # Si es el mejor modelo hasta ahora, lo guardamos
        if mean_reward > best_mean_reward:
            best_mean_reward = mean_reward
            torch.save(mario.net.state_dict(), '/kaggle/working/best_mario_model.pth')
            print(f"✅ Modelo guardado en episodio {e} con reward promedio {best_mean_reward:.2f}")

        torch.cuda.empty_cache()
        gc.collect()
# Out:
# Using CUDA: True
#
# Episode:   0  :: Step:   41  :: Epsilon:   1.000  :: Mean_Reward: 239.000  :: Mean_Length:  41.000  :: Mean_Loss:0.000  :: Mean_Q_Value:   0.000  :: Time_Delta:   0.484
# ✅ Modelo guardado en episodio 0 con reward promedio 239.00
# Episode:  25  :: Step: 8963  :: Epsilon:   0.998  :: Mean_Reward: 550.269  :: Mean_Length: 344.731  :: Mean_Loss:0.000  :: Mean_Q_Value:   0.000  :: Time_Delta: 102.876
# ✅ Modelo guardado en episodio 25 con reward promedio 550.27
# Episode:  50  :: Step:17574  :: Epsilon:   0.996  :: Mean_Reward: 591.784  :: Mean_Length: 344.588  :: Mean_Loss:0.756  :: Mean_Q_Value:   0.461  :: Time_Delta: 108.775
# ✅ Modelo guardado en episodio 50 con reward promedio 591.78
# Episode:  75  :: Step:26038  :: Epsilon:   0.994  :: Mean_Reward: 596.539  :: Mean_Length: 342.605  :: Mean_Loss:0.900  :: Mean_Q_Value:   1.280  :: Time_Delta: 106.089
# ✅ Modelo guardado en episodio 75 con reward promedio 596.54
# Episode: 100  :: Step:35194  :: Epsilon:   0.991  :: Mean_Reward: 625.760  :: Mean_Length: 351.530  :: Mean_Loss:1.015  :: Mean_Q_Value:   2.088  :: Time_Delta: 113.331
# ✅ Modelo guardado en episodio 100 con reward promedio 625.76
# Episode: 125  :: Step:43373  :: Epsilon:   0.989  :: Mean_Reward: 622.360  :: Mean_Length: 344.100  :: Mean_Loss:1.335  :: Mean_Q_Value:   3.413  :: Time_Delta: 102.189
# Episode: 150  :: Step:50189  :: Epsilon:   0.988  :: Mean_Reward: 600.840  :: Mean_Length: 326.150  :: Mean_Loss:1.263  :: Mean_Q_Value:   4.638  :: Time_Delta:  84.464
# Episode: 175  :: Step:67087  :: Epsilon:   0.983  :: Mean_Reward: 595.540  :: Mean_Length: 410.490  :: Mean_Loss:1.261  :: Mean_Q_Value:   5.298  :: Time_Delta: 211.852
# Episode: 200  :: Step:78234  :: Epsilon:   0.981  :: Mean_Reward: 570.870  :: Mean_Length: 430.400  :: Mean_Loss:1.198  :: Mean_Q_Value:   5.397  :: Time_Delta: 139.933
# Episode: 225  :: Step:87428  :: Epsilon:   0.978  :: Mean_Reward: 576.510  :: Mean_Length: 440.550  :: Mean_Loss:1.222  :: Mean_Q_Value:   5.895  :: Time_Delta: 116.048
# Episode: 250  :: Step:94924  :: Epsilon:   0.977  :: Mean_Reward: 570.360  :: Mean_Length: 447.350  :: Mean_Loss:1.296  :: Mean_Q_Value:   6.858  :: Time_Delta:  93.219
# Episode: 275  :: Step:102549  :: Epsilon:   0.975  :: Mean_Reward: 562.670  :: Mean_Length: 354.620  :: Mean_Loss:1.381  :: Mean_Q_Value:   8.152  :: Time_Delta:  95.541
# Episode: 300  :: Step:113695  :: Epsilon:   0.972  :: Mean_Reward: 563.710  :: Mean_Length: 354.610  :: Mean_Loss:1.512  :: Mean_Q_Value:   9.837  :: Time_Delta: 139.905
# Episode: 325  :: Step:123630  :: Epsilon:   0.970  :: Mean_Reward: 539.230  :: Mean_Length: 362.020  :: Mean_Loss:1.584  :: Mean_Q_Value:  10.726  :: Time_Delta: 124.705
# Episode: 350  :: Step:135677  :: Epsilon:   0.967  :: Mean_Reward: 563.490  :: Mean_Length: 407.530  :: Mean_Loss:1.573  :: Mean_Q_Value:  10.745  :: Time_Delta: 149.889
# Episode: 375  :: Step:142880  :: Epsilon:   0.965  :: Mean_Reward: 577.820  :: Mean_Length: 403.310  :: Mean_Loss:1.613  :: Mean_Q_Value:  11.014  :: Time_Delta:  90.549
# Episode: 400  :: Step:151236  :: Epsilon:   0.963  :: Mean_Reward: 569.190  :: Mean_Length: 375.410  :: Mean_Loss:1.694  :: Mean_Q_Value:  11.406  :: Time_Delta: 104.868
# Episode: 425  :: Step:162994  :: Epsilon:   0.960  :: Mean_Reward: 580.200  :: Mean_Length: 393.640  :: Mean_Loss:1.714  :: Mean_Q_Value:  11.932  :: Time_Delta: 148.737
# Episode: 450  :: Step:177405  :: Epsilon:   0.957  :: Mean_Reward: 589.810  :: Mean_Length: 417.280  :: Mean_Loss:1.753  :: Mean_Q_Value:  12.304  :: Time_Delta: 185.092
# Episode: 475  :: Step:186106  :: Epsilon:   0.955  :: Mean_Reward: 579.930  :: Mean_Length: 432.260  :: Mean_Loss:1.763  :: Mean_Q_Value:  12.106  :: Time_Delta: 110.279
# Episode: 500  :: Step:195058  :: Epsilon:   0.952  :: Mean_Reward: 576.660  :: Mean_Length: 438.220  :: Mean_Loss:1.757  :: Mean_Q_Value:  12.126  :: Time_Delta: 113.311
# Episode: 525  :: Step:206593  :: Epsilon:   0.950  :: Mean_Reward: 603.990  :: Mean_Length: 435.990  :: Mean_Loss:1.798  :: Mean_Q_Value:  12.265  :: Time_Delta: 145.149
# Episode: 550  :: Step:213749  :: Epsilon:   0.948  :: Mean_Reward: 591.810  :: Mean_Length: 363.440  :: Mean_Loss:1.885  :: Mean_Q_Value:  13.129  :: Time_Delta:  89.848
# Episode: 575  :: Step:221289  :: Epsilon:   0.946  :: Mean_Reward: 574.160  :: Mean_Length: 351.830  :: Mean_Loss:1.961  :: Mean_Q_Value:  14.285  :: Time_Delta:  94.510
# Episode: 600  :: Step:232922  :: Epsilon:   0.943  :: Mean_Reward: 579.170  :: Mean_Length: 378.640  :: Mean_Loss:2.020  :: Mean_Q_Value:  15.482  :: Time_Delta: 146.711
# Episode: 625  :: Step:244791  :: Epsilon:   0.941  :: Mean_Reward: 587.790  :: Mean_Length: 381.980  :: Mean_Loss:2.038  :: Mean_Q_Value:  15.861  :: Time_Delta: 149.981
# Episode: 650  :: Step:256152  :: Epsilon:   0.938  :: Mean_Reward: 579.320  :: Mean_Length: 424.030  :: Mean_Loss:2.041  :: Mean_Q_Value:  15.949  :: Time_Delta: 142.435
# Episode: 675  :: Step:270932  :: Epsilon:   0.935  :: Mean_Reward: 610.400  :: Mean_Length: 496.430  :: Mean_Loss:1.981  :: Mean_Q_Value:  15.152  :: Time_Delta: 187.836
# Episode: 700  :: Step:281753  :: Epsilon:   0.932  :: Mean_Reward: 599.680  :: Mean_Length: 488.310  :: Mean_Loss:1.882  :: Mean_Q_Value:  13.873  :: Time_Delta: 135.313
# Episode: 725  :: Step:292369  :: Epsilon:   0.930  :: Mean_Reward: 578.050  :: Mean_Length: 475.780  :: Mean_Loss:1.862  :: Mean_Q_Value:  13.695  :: Time_Delta: 133.593
# Episode: 750  :: Step:302452  :: Epsilon:   0.927  :: Mean_Reward: 561.890  :: Mean_Length: 463.000  :: Mean_Loss:1.859  :: Mean_Q_Value:  13.801  :: Time_Delta: 125.776
# Episode: 775  :: Step:312818  :: Epsilon:   0.925  :: Mean_Reward: 545.380  :: Mean_Length: 418.860  :: Mean_Loss:1.946  :: Mean_Q_Value:  14.928  :: Time_Delta: 130.182
# Episode: 800  :: Step:319307  :: Epsilon:   0.923  :: Mean_Reward: 536.640  :: Mean_Length: 375.540  :: Mean_Loss:2.032  :: Mean_Q_Value:  15.908  :: Time_Delta:  80.659
# Episode: 825  :: Step:328161  :: Epsilon:   0.921  :: Mean_Reward: 549.730  :: Mean_Length: 357.920  :: Mean_Loss:2.091  :: Mean_Q_Value:  17.042  :: Time_Delta: 112.278
# Episode: 850  :: Step:334063  :: Epsilon:   0.920  :: Mean_Reward: 549.800  :: Mean_Length: 316.110  :: Mean_Loss:2.215  :: Mean_Q_Value:  18.741  :: Time_Delta:  73.449
# Episode: 875  :: Step:344074  :: Epsilon:   0.918  :: Mean_Reward: 543.050  :: Mean_Length: 312.560  :: Mean_Loss:2.299  :: Mean_Q_Value:  19.951  :: Time_Delta: 125.107
# Episode: 900  :: Step:353446  :: Epsilon:   0.915  :: Mean_Reward: 570.790  :: Mean_Length: 341.390  :: Mean_Loss:2.296  :: Mean_Q_Value:  20.567  :: Time_Delta: 117.818
# Episode: 925  :: Step:363587  :: Epsilon:   0.913  :: Mean_Reward: 564.180  :: Mean_Length: 354.260  :: Mean_Loss:2.289  :: Mean_Q_Value:  20.533  :: Time_Delta: 129.215
# Episode: 950  :: Step:372517  :: Epsilon:   0.911  :: Mean_Reward: 573.000  :: Mean_Length: 384.540  :: Mean_Loss:2.242  :: Mean_Q_Value:  19.477  :: Time_Delta: 115.024
# Episode: 975  :: Step:381754  :: Epsilon:   0.909  :: Mean_Reward: 575.220  :: Mean_Length: 376.800  :: Mean_Loss:2.115  :: Mean_Q_Value:  18.204  :: Time_Delta: 119.031
# Episode:1000  :: Step:393267  :: Epsilon:   0.906  :: Mean_Reward: 576.200  :: Mean_Length: 398.210  :: Mean_Loss:2.102  :: Mean_Q_Value:  17.857  :: Time_Delta: 146.897
# Episode:1025  :: Step:401319  :: Epsilon:   0.905  :: Mean_Reward: 559.880  :: Mean_Length: 377.320  :: Mean_Loss:2.004  :: Mean_Q_Value:  17.369  :: Time_Delta: 102.972
# Episode:1050  :: Step:410314  :: Epsilon:   0.903  :: Mean_Reward: 582.970  :: Mean_Length: 377.970  :: Mean_Loss:1.934  :: Mean_Q_Value:  16.990  :: Time_Delta: 114.283
# Episode:1075  :: Step:418331  :: Epsilon:   0.901  :: Mean_Reward: 595.760  :: Mean_Length: 365.770  :: Mean_Loss:1.948  :: Mean_Q_Value:  17.579  :: Time_Delta: 101.764
# Episode:1100  :: Step:430357  :: Epsilon:   0.898  :: Mean_Reward: 598.990  :: Mean_Length: 370.900  :: Mean_Loss:1.982  :: Mean_Q_Value:  17.674  :: Time_Delta: 154.895
# Episode:1125  :: Step:446315  :: Epsilon:   0.894  :: Mean_Reward: 637.310  :: Mean_Length: 449.960  :: Mean_Loss:1.916  :: Mean_Q_Value:  16.936  :: Time_Delta: 203.112
# ✅ Modelo guardado en episodio 1125 con reward promedio 637.31
# Episode:1150  :: Step:458246  :: Epsilon:   0.892  :: Mean_Reward: 633.210  :: Mean_Length: 479.320  :: Mean_Loss:1.792  :: Mean_Q_Value:  15.567  :: Time_Delta: 152.155
# Episode:1175  :: Step:465432  :: Epsilon:   0.890  :: Mean_Reward: 625.030  :: Mean_Length: 471.010  :: Mean_Loss:1.716  :: Mean_Q_Value:  14.308  :: Time_Delta:  92.294
# Episode:1200  :: Step:474235  :: Epsilon:   0.888  :: Mean_Reward: 595.680  :: Mean_Length: 438.780  :: Mean_Loss:1.694  :: Mean_Q_Value:  13.946  :: Time_Delta: 112.354
# Episode:1225  :: Step:480360  :: Epsilon:   0.887  :: Mean_Reward: 541.450  :: Mean_Length: 340.450  :: Mean_Loss:1.823  :: Mean_Q_Value:  14.975  :: Time_Delta:  78.845
# Episode:1250  :: Step:493653  :: Epsilon:   0.884  :: Mean_Reward: 549.960  :: Mean_Length: 354.070  :: Mean_Loss:1.929  :: Mean_Q_Value:  16.334  :: Time_Delta: 168.507
# Episode:1275  :: Step:500309  :: Epsilon:   0.882  :: Mean_Reward: 570.030  :: Mean_Length: 348.770  :: Mean_Loss:1.942  :: Mean_Q_Value:  16.658  :: Time_Delta:  84.425
# Episode:1300  :: Step:508425  :: Epsilon:   0.881  :: Mean_Reward: 580.420  :: Mean_Length: 341.900  :: Mean_Loss:1.973  :: Mean_Q_Value:  16.794  :: Time_Delta: 102.531
# Episode:1325  :: Step:516900  :: Epsilon:   0.879  :: Mean_Reward: 616.070  :: Mean_Length: 365.400  :: Mean_Loss:2.048  :: Mean_Q_Value:  17.178  :: Time_Delta: 105.471
# Episode:1350  :: Step:530993  :: Epsilon:   0.876  :: Mean_Reward: 585.670  :: Mean_Length: 373.400  :: Mean_Loss:2.004  :: Mean_Q_Value:  16.745  :: Time_Delta: 182.119
# Episode:1375  :: Step:543810  :: Epsilon:   0.873  :: Mean_Reward: 565.730  :: Mean_Length: 435.010  :: Mean_Loss:1.947  :: Mean_Q_Value:  15.636  :: Time_Delta: 163.978
# Episode:1400  :: Step:548919  :: Epsilon:   0.872  :: Mean_Reward: 575.370  :: Mean_Length: 404.940  :: Mean_Loss:1.854  :: Mean_Q_Value:  14.817  :: Time_Delta:  65.274
# Episode:1425  :: Step:558628  :: Epsilon:   0.870  :: Mean_Reward: 546.620  :: Mean_Length: 417.280  :: Mean_Loss:1.756  :: Mean_Q_Value:  14.124  :: Time_Delta: 123.198
# Episode:1450  :: Step:570635  :: Epsilon:   0.867  :: Mean_Reward: 565.350  :: Mean_Length: 396.420  :: Mean_Loss:1.743  :: Mean_Q_Value:  14.232  :: Time_Delta: 151.620
# Episode:1475  :: Step:579161  :: Epsilon:   0.865  :: Mean_Reward: 548.980  :: Mean_Length: 353.510  :: Mean_Loss:1.737  :: Mean_Q_Value:  14.513  :: Time_Delta: 107.474
# Episode:1500  :: Step:591449  :: Epsilon:   0.863  :: Mean_Reward: 529.820  :: Mean_Length: 425.300  :: Mean_Loss:1.706  :: Mean_Q_Value:  14.173  :: Time_Delta: 157.606
# Episode:1525  :: Step:599912  :: Epsilon:   0.861  :: Mean_Reward: 564.250  :: Mean_Length: 412.840  :: Mean_Loss:1.658  :: Mean_Q_Value:  13.083  :: Time_Delta: 109.184
# Episode:1550  :: Step:612896  :: Epsilon:   0.858  :: Mean_Reward: 557.910  :: Mean_Length: 422.610  :: Mean_Loss:1.596  :: Mean_Q_Value:  12.199  :: Time_Delta: 166.402
# Episode:1575  :: Step:625792  :: Epsilon:   0.855  :: Mean_Reward: 568.530  :: Mean_Length: 466.310  :: Mean_Loss:1.542  :: Mean_Q_Value:  11.742  :: Time_Delta: 162.673
# Episode:1600  :: Step:635483  :: Epsilon:   0.853  :: Mean_Reward: 594.370  :: Mean_Length: 440.340  :: Mean_Loss:1.546  :: Mean_Q_Value:  11.605  :: Time_Delta: 121.208
# Episode:1625  :: Step:643703  :: Epsilon:   0.851  :: Mean_Reward: 576.140  :: Mean_Length: 437.910  :: Mean_Loss:1.638  :: Mean_Q_Value:  12.431  :: Time_Delta: 102.912
# Episode:1650  :: Step:654824  :: Epsilon:   0.849  :: Mean_Reward: 559.200  :: Mean_Length: 419.280  :: Mean_Loss:1.715  :: Mean_Q_Value:  12.969  :: Time_Delta: 139.648
# Episode:1675  :: Step:664852  :: Epsilon:   0.847  :: Mean_Reward: 589.440  :: Mean_Length: 390.600  :: Mean_Loss:1.825  :: Mean_Q_Value:  13.750  :: Time_Delta: 126.808
# Episode:1700  :: Step:673421  :: Epsilon:   0.845  :: Mean_Reward: 578.860  :: Mean_Length: 379.380  :: Mean_Loss:1.871  :: Mean_Q_Value:  14.543  :: Time_Delta: 109.508
# Episode:1725  :: Step:690932  :: Epsilon:   0.841  :: Mean_Reward: 579.350  :: Mean_Length: 472.290  :: Mean_Loss:1.770  :: Mean_Q_Value:  13.747  :: Time_Delta: 224.669
# Episode:1750  :: Step:706124  :: Epsilon:   0.838  :: Mean_Reward: 594.780  :: Mean_Length: 513.000  :: Mean_Loss:1.697  :: Mean_Q_Value:  12.813  :: Time_Delta: 195.558
# Episode:1775  :: Step:722302  :: Epsilon:   0.835  :: Mean_Reward: 579.440  :: Mean_Length: 574.500  :: Mean_Loss:1.571  :: Mean_Q_Value:  11.562  :: Time_Delta: 208.845
# Episode:1800  :: Step:732195  :: Epsilon:   0.833  :: Mean_Reward: 570.540  :: Mean_Length: 587.740  :: Mean_Loss:1.400  :: Mean_Q_Value:   9.963  :: Time_Delta: 130.053
# Episode:1825  :: Step:736580  :: Epsilon:   0.832  :: Mean_Reward: 548.220  :: Mean_Length: 456.480  :: Mean_Loss:1.384  :: Mean_Q_Value:   9.849  :: Time_Delta:  56.009
# Episode:1850  :: Step:748145  :: Epsilon:   0.829  :: Mean_Reward: 528.480  :: Mean_Length: 420.210  :: Mean_Loss:1.447  :: Mean_Q_Value:  10.864  :: Time_Delta: 149.756
# Episode:1875  :: Step:755188  :: Epsilon:   0.828  :: Mean_Reward: 503.110  :: Mean_Length: 328.860  :: Mean_Loss:1.600  :: Mean_Q_Value:  12.344  :: Time_Delta:  97.884
# Episode:1900  :: Step:770351  :: Epsilon:   0.825  :: Mean_Reward: 508.130  :: Mean_Length: 381.560  :: Mean_Loss:1.748  :: Mean_Q_Value:  13.412  :: Time_Delta: 199.178
# Episode:1925  :: Step:778259  :: Epsilon:   0.823  :: Mean_Reward: 506.140  :: Mean_Length: 416.790  :: Mean_Loss:1.663  :: Mean_Q_Value:  12.903  :: Time_Delta: 102.990
# Episode:1950  :: Step:788609  :: Epsilon:   0.821  :: Mean_Reward: 539.350  :: Mean_Length: 404.640  :: Mean_Loss:1.615  :: Mean_Q_Value:  12.419  :: Time_Delta: 132.106
# Episode:1975  :: Step:795832  :: Epsilon:   0.820  :: Mean_Reward: 584.280  :: Mean_Length: 406.440  :: Mean_Loss:1.597  :: Mean_Q_Value:  12.861  :: Time_Delta:  91.860
# Episode:2000  :: Step:808205  :: Epsilon:   0.817  :: Mean_Reward: 594.060  :: Mean_Length: 378.540  :: Mean_Loss:1.681  :: Mean_Q_Value:  14.105  :: Time_Delta: 156.899

# %%
# !pip --disable-pip-version-check install -q pyvirtualdisplay

from pyvirtualdisplay import Display

from IPython import display as ipythondisplay
from IPython.display import HTML

from gym.wrappers import Monitor
from glob import glob

import base64
import io

display = Display(visible=0, size=(600, 300))
display.start()

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
    mp4list = glob('/kaggle/working/video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                 </video>'''.format(encoded.decode('ascii'))))
    else: 
        print("Could not find video")
    

def wrap_env(env):
    env = Monitor(env, '/kaggle/working/video', force=True)
    return env

env = wrap_env(env)

# %% [markdown]
# # Play a game

# %%
state = env.reset()

# Play the game!
while True:

    # Run agent on the state
    action = mario.act(state)

    # Agent performs action
    next_state, reward, done, info = env.step(action)

    # Update state
    state = next_state
    
    # Check if end of game
    if done or info["flag_get"]:
        break

env.close()
show_video()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dcedccb3bbab> in <module>
# ----> 1 state = env.reset()
#       2
#       3 # Play the game!
#       4 while True:
#       5
#
# NameError: name 'env' is not defined

# %%
# Crear entorno como en entrenamiento
rand_env = gym_super_mario_bros.make("SuperMarioBros-1-1-v0")
rand_env = JoypadSpace(rand_env, SIMPLE_MOVEMENT)
rand_env = SkipFrame(rand_env, skip=4)
rand_env = GrayScaleObservation(rand_env)
rand_env = ResizeObservation(rand_env, shape=84)
rand_env = FrameStack(rand_env, num_stack=4)

# Reiniciar entorno
state = rand_env.reset()

# Jugar de forma aleatoria
while True:
    # Acción aleatoria
    action = rand_env.action_space.sample()

    # Ejecutar acción
    next_state, reward, done, info = rand_env.step(action)

    # Actualizar estado
    state = next_state

    # Verificar si terminó el episodio
    if done or info["flag_get"]:
        break

rand_env.close()

# Mostrar el video inline como ya lo haces
show_video()
# Out:
# <video alt="test" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
